# %% [markdown]
# <a href="https://colab.research.google.com/github/zubaidah93/hello-world/blob/master/FUCKYES_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

"""
Created on Sat Nov 14 21:07:30 2020

@author: zobidasabah
"""
#connect google drive in Colab
from google.colab import drive
drive.mount('/content/drive')

#import libraries

import numpy as np
import cPickle as pickle
import cv2
import os
import matplotlib.pyplot as plt
from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
import tensorflow as tf
from threading import Thread 

#########################################


# Dimension of resized image
DEFAULT_IMAGE_SIZE = tuple((256, 256))
# Number of images used to train the model
N_IMAGES = 700

# Path to the dataset folder
root_dir = './drive/MyDrive/disease classification/dataset'

train_dir = os.path.join(root_dir, 'train')
val_dir = os.path.join(root_dir, 'val')

def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None:
            image = cv2.resize(image, DEFAULT_IMAGE_SIZE)   
            return img_to_array(image)
        else:
            return np.array([])
    except Exception as e:
        print("Error : {e}")
        return None 

print("Done converting")

image_list, label_list = [], []

try:
    
    plant_disease_folder_list = listdir(train_dir)
    for directory in train_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            train_dir.remove(directory)
    print("[INFO] .DS_Store files removed")
  
    print("[INFO] Files and directories in ./. ")  
    print(plant_disease_folder_list)
    print("[INFO] Loading images ...")

    for plant_disease_folder in plant_disease_folder_list:

      plant_disease_image_list = listdir(train_dir+'/'+plant_disease_folder)
      
      for image in plant_disease_image_list[:N_IMAGES]:
          image_directory = train_dir+'/'+plant_disease_folder+'/'+image
          if image_directory.endswith(".jpg")==True or image_directory.endswith(".JPG")==True:
               image_list.append(convert_image_to_array(image_directory))
               label_list.append(plant_disease_folder)
      print('[INFO] Loading',plant_disease_folder)

    print("[INFO] Image loading completed")  
except Exception, e:
    print("Error :",e)
# Transform the loaded training image data into numpy array

np_image_list = np.array(image_list, dtype=np.float16) / 225.0
print('[INFO] Transform the loaded training image data into numpy array Complete')

# Check the number of images loaded for training
image_len = len(image_list)
print("Total number of images: ", image_len)

#check the number of classes 


label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)

pickle.dump(label_binarizer,open('plant_disease_label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

print("Total number of classes: ", n_classes)

augment = ImageDataGenerator(rotation_range=25, width_shift_range=0.1,
                             height_shift_range=0.1, shear_range=0.2, 
                             zoom_range=0.2, horizontal_flip=True, 
                             fill_mode="nearest")

print("[INFO] Splitting data to train and test...")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 1, stratify=image_labels)


#Build Model

EPOCHS = 80
LR = 1e-4
BATCH_SIZE = 32
WIDTH = 256
HEIGHT = 256
DEPTH = 3

#Creating a sequential model and adding Convolutional, Normalization, Pooling, Dropout and Activation layers at the appropriate positions.
print("[INFO] Summay of creating a sequential model and adding layers at the appropriate positions")
model = Sequential()
inputShape = (HEIGHT, WIDTH, DEPTH)
chanDim = -1

if K.image_data_format() == "channels_first":
    inputShape = (DEPTH, HEIGHT, WIDTH)
    chanDim = 1

model.add(Conv2D(32, (3, 3), padding="same",input_shape=inputShape))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Dropout(0.25))
model.add(Conv2D(64, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(Conv2D(64, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(128, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(Conv2D(128, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(1024))
model.add(Activation("relu"))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(n_classes))
model.add(Activation("softmax"))

model.summary()
#############################################

#Train Model

# Initialize optimizer
opt = Adam(lr=LR, decay=LR / EPOCHS)

# Compile model
model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["accuracy"])

# Train model
print("[INFO] Training network...")
history = model.fit(augment.flow(x_train, y_train, batch_size=BATCH_SIZE),
                              validation_data=(x_test, y_test),
                              steps_per_epoch=len(x_train) // BATCH_SIZE,
                              epochs=EPOCHS, 
                              verbose=1)

#Evaluate model

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

# Train and validation accuracy
plt.plot(epochs, acc, 'b', label='Training accurarcy')
plt.plot(epochs, val_acc, 'r', label='Validation accurarcy')
plt.title('Training and Validation accurarcy')
plt.legend()

plt.figure()

# Train and validation loss
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()
plt.show()

#accuracy evaluation

print("[INFO] Calculating model accuracy")
scores = model.evaluate(x_test, y_test)
print("Test accuracy = ", (scores[1]*100))

#######################################

#pickle the trained model 


with open('plant_disease_classification_model.pkl', 'wb') as f:
    pickle.dump(history.history, f)
# Dump pickle file of the labels
print("[INFO] Saving label transform...")
filename = 'plant_disease_label_transform.pkl'
image_labels = pickle.load(open(filename, 'rb'))

###############################

#Test_Model
def predict_disease(image_path):
    image_array = convert_image_to_array(image_path)
    np_image = np.array(image_array, dtype=np.float16) / 225.0
    np_image = np.expand_dims(np_image,0)
    plt.imshow(plt.imread(image_path))
    result= np.argmax(model.predict(np_image), axis=-1)
    #result = model.predict_classes(np_image)
    print((image_labels.classes_[result][0]))
  
predict_disease('/content/drive/MyDrive/disease classification/0ced0bae-d224-43f5-8fd7-072c7cbd8f77___Crnl_L.Mold 9161.JPG')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Using TensorFlow backend.
# Done converting
# [INFO] .DS_Store files removed
# [INFO] Files and directories in ./.
# ['Tomato___Leaf_Mold', 'Tomato___Tomato_mosaic_virus', 'Tomato___healthy', 'Tomato___Septoria_leaf_spot', 'Tomato___Early_blight', 'Tomato___Target_Spot', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Tomato___Bacterial_spot', 'Tomato___Late_blight', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus']
# [INFO] Loading images ...
# ('[INFO] Loading', 'Tomato___Leaf_Mold')
# ('[INFO] Loading', 'Tomato___Tomato_mosaic_virus')
# ('[INFO] Loading', 'Tomato___healthy')
# ('[INFO] Loading', 'Tomato___Septoria_leaf_spot')
# ('[INFO] Loading', 'Tomato___Early_blight')
# ('[INFO] Loading', 'Tomato___Target_Spot')
# ('[INFO] Loading', 'Tomato___Spider_mites Two-spotted_spider_mite')
# ('[INFO] Loading', 'Tomato___Bacterial_spot')
# ('[INFO] Loading', 'Tomato___Late_blight')
# ('[INFO] Loading', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus')
# [INFO] Image loading completed
# [INFO] Transform the loaded training image data into numpy array Complete
# ('Total number of images: ', 6598)
# ('Total number of classes: ', 10)
# [INFO] Splitting data to train and test...
# [INFO] Summay of creating a sequential model and adding layers at the appropriate positions
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 256, 256, 32)      896
# _________________________________________________________________
# activation_1 (Activation)    (None, 256, 256, 32)      0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256, 256, 32)      128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 85, 85, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 85, 85, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 85, 85, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 85, 85, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 85, 85, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 85, 85, 64)        36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 85, 85, 64)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 85, 85, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 42, 42, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 42, 42, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 42, 42, 128)       73856
# _________________________________________________________________
# activation_4 (Activation)    (None, 42, 42, 128)       0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 42, 42, 128)       512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 42, 42, 128)       147584
# _________________________________________________________________
# activation_5 (Activation)    (None, 42, 42, 128)       0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 42, 42, 128)       512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 21, 21, 128)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 21, 21, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 56448)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              57803776
# _________________________________________________________________
# activation_6 (Activation)    (None, 1024)              0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                10250
# _________________________________________________________________
# activation_7 (Activation)    (None, 10)                0
# =================================================================
# Total params: 58,097,546
# Trainable params: 58,094,666
# Non-trainable params: 2,880
# _________________________________________________________________
# [INFO] Training network...
# Epoch 1/80
# 164/164 [==============================] - 185s 1s/step - loss: 0.2253 - accuracy: 0.9197 - val_loss: 0.9621 - val_accuracy: 0.8212
# Epoch 2/80
# 164/164 [==============================] - 188s 1s/step - loss: 0.1480 - accuracy: 0.9452 - val_loss: 1.9494 - val_accuracy: 0.8217
# Epoch 3/80
# 164/164 [==============================] - 188s 1s/step - loss: 0.1261 - accuracy: 0.9544 - val_loss: 0.7401 - val_accuracy: 0.8607
# Epoch 4/80
# 164/164 [==============================] - 189s 1s/step - loss: 0.1121 - accuracy: 0.9586 - val_loss: 0.4533 - val_accuracy: 0.8940
# Epoch 5/80
# 164/164 [==============================] - 189s 1s/step - loss: 0.1026 - accuracy: 0.9612 - val_loss: 0.5085 - val_accuracy: 0.9008
# Epoch 6/80
# 164/164 [==============================] - 187s 1s/step - loss: 0.0903 - accuracy: 0.9666 - val_loss: 0.4985 - val_accuracy: 0.9098
# Epoch 7/80
# 164/164 [==============================] - 188s 1s/step - loss: 0.0845 - accuracy: 0.9681 - val_loss: 0.7838 - val_accuracy: 0.8898
# Epoch 8/80
# 164/164 [==============================] - 188s 1s/step - loss: 0.0794 - accuracy: 0.9695 - val_loss: 0.5568 - val_accuracy: 0.9018
# Epoch 9/80
# 164/164 [==============================] - 189s 1s/step - loss: 0.0727 - accuracy: 0.9726 - val_loss: 0.6124 - val_accuracy: 0.9017
# Epoch 10/80
# 164/164 [==============================] - 189s 1s/step - loss: 0.0693 - accuracy: 0.9743 - val_loss: 0.3509 - val_accuracy: 0.9235
# Epoch 11/80
# 164/164 [==============================] - 189s 1s/step - loss: 0.0633 - accuracy: 0.9764 - val_loss: 0.4731 - val_accuracy: 0.9077
# Epoch 12/80
# 164/164 [==============================] - 194s 1s/step - loss: 0.0634 - accuracy: 0.9761 - val_loss: 0.4037 - val_accuracy: 0.9136
# Epoch 13/80
# 164/164 [==============================] - 188s 1s/step - loss: 0.0601 - accuracy: 0.9775 - val_loss: 0.5130 - val_accuracy: 0.9009
# Epoch 14/80
# 164/164 [==============================] - 188s 1s/step - loss: 0.
80
# 164/164 [==============================] - 188s 1s/step - loss: 0.0220 - accuracy: 0.9921 - val_loss: 0.0957 - val_accuracy: 0.9717
# Epoch 60/80
# 164/164 [==============================] - 188s 1s/step - loss: 0.0181 - accuracy: 0.9932 - val_loss: 0.1011 - val_accuracy: 0.9680
# Epoch 61/80
# 164/164 [==============================] - 187s 1s/step - loss: 0.0224 - accuracy: 0.9924 - val_loss: 0.3489 - val_accuracy: 0.9383
# Epoch 62/80
# 164/164 [==============================] - 186s 1s/step - loss: 0.0190 - accuracy: 0.9926 - val_loss: 0.3448 - val_accuracy: 0.9369
# Epoch 63/80
# 164/164 [==============================] - 184s 1s/step - loss: 0.0174 - accuracy: 0.9934 - val_loss: 0.1894 - val_accuracy: 0.9606
# Epoch 64/80
# 164/164 [==============================] - 186s 1s/step - loss: 0.0172 - accuracy: 0.9938 - val_loss: 0.1133 - val_accuracy: 0.9686
# Epoch 65/80
# 164/164 [==============================] - 188s 1s/step - loss: 0.0155 - accuracy: 0.9944 - val_loss: 0.2188 - val_accuracy: 0.9511
# Epoch 66/80
# 164/164 [==============================] - 188s 1s/step - loss: 0.0166 - accuracy: 0.9935 - val_loss: 0.1513 - val_accuracy: 0.9622
# Epoch 67/80
# 164/164 [==============================] - 188s 1s/step - loss: 0.0142 - accuracy: 0.9947 - val_loss: 0.1221 - val_accuracy: 0.9706
# Epoch 68/80
# 164/164 [==============================] - 186s 1s/step - loss: 0.0211 - accuracy: 0.9925 - val_loss: 0.2954 - val_accuracy: 0.9455
# Epoch 69/80
# 164/164 [==============================] - 188s 1s/step - loss: 0.0194 - accuracy: 0.9930 - val_loss: 0.2633 - val_accuracy: 0.9515
# Epoch 70/80
# 164/164 [==============================] - 187s 1s/step - loss: 0.0166 - accuracy: 0.9937 - val_loss: 0.2619 - val_accuracy: 0.9504
# Epoch 71/80
# 164/164 [==============================] - 186s 1s/step - loss: 0.0158 - accuracy: 0.9948 - val_loss: 0.0860 - val_accuracy: 0.9773
# Epoch 72/80
# 164/164 [==============================] - 188s 1s/step - loss: 0.0131 - accuracy: 0.9954 - val_loss: 0.1019 - val_accuracy: 0.9697
# Epoch 73/80
# 164/164 [==============================] - 186s 1s/step - loss: 0.0150 - accuracy: 0.9945 - val_loss: 0.1242 - val_accuracy: 0.9708
# Epoch 74/80
# 164/164 [==============================] - 187s 1s/step - loss: 0.0145 - accuracy: 0.9951 - val_loss: 0.1844 - val_accuracy: 0.9627
# Epoch 75/80
# 164/164 [==============================] - 187s 1s/step - loss: 0.0162 - accuracy: 0.9941 - val_loss: 0.1950 - val_accuracy: 0.9574
# Epoch 76/80
# 164/164 [==============================] - 186s 1s/step - loss: 0.0130 - accuracy: 0.9953 - val_loss: 0.1939 - val_accuracy: 0.9598
# Epoch 77/80
# 164/164 [==============================] - 188s 1s/step - loss: 0.0147 - accuracy: 0.9943 - val_loss: 0.1367 - val_accuracy: 0.9684
# Epoch 78/80
# 164/164 [==============================] - 188s 1s/step - loss: 0.0137 - accuracy: 0.9951 - val_loss: 0.2036 - val_accuracy: 0.9589
# Epoch 79/80
# 164/164 [==============================] - 185s 1s/step - loss: 0.0105 - accuracy: 0.9962 - val_loss: 0.1675 - val_accuracy: 0.9643
# Epoch 80/80
# 164/164 [==============================] - 181s 1s/step - loss: 0.0101 - accuracy: 0.9959 - val_loss: 0.1649 - val_accuracy: 0.9628
# [INFO] Calculating model accuracy
# 1320/1320 [==============================] - 8s 6ms/step
# ('Test accuracy = ', 96.28028869628906)
# [INFO] Saving label transform...
# Tomato___Leaf_Mold
